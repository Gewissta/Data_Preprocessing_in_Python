# %%
# импортируем необходимые библиотеки, классы и функции
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
# увеличиваем количество строк вывода
pd.set_option('display.max_rows', 400)

# %%
# загружаем данные
data = pd.read_csv('Data/santander_train.csv')

# %%
# удаляем ID
data.drop('ID', axis=1, inplace=True)

# %%
# разбиваем набор данных на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(
    data.drop('TARGET', axis=1),
    data['TARGET'],
    test_size=0.3,
    random_state=42)

# смотрим количество наблюдений и признаков
print(X_train.shape, X_test.shape)
# Out:
# (53214, 369) (22806, 369)

# %%
# импортируем необходимые классы и функции 
# для нашей функции importance_auc()
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score

# пишем функцию, вычисляющую AUC для модели с одним признаком
def importance_auc(train, y_train, imp_strategy):
    # задаем количество десятичных разрядов
    pd.set_option('display.precision', 3)
    # создаем копию обучающего набора
    train_copy = train.copy()
    # создаем список признаков
    col_list = train_copy.select_dtypes(include=['number']).columns
    # создаем пустой список, в который будем записывать значения AUC
    auc_list = []
    # вычисляем AUC для модели с одним признаком,
    # используя перекрестную проверку
    for i in col_list:
        pipe = Pipeline([('imputer', SimpleImputer(strategy=imp_strategy)),
                         ('scaler', StandardScaler()), 
                         ('logreg', LogisticRegression(solver='liblinear'))])     
        auc = cross_val_score(pipe, train_copy[[i]], y_train, 
                              scoring='roc_auc', cv=5).mean()
        # добавляем значение AUC в список
        auc_list.append(auc)
    # превращаем список со значениями AUC в серию
    auc_values = pd.Series(auc_list)
    # метками индекса будут имена признаков
    auc_values.index = col_list
    # сортируем по убыванию
    auc_values = auc_values.sort_values(ascending=False)
    return auc_values

# %%
# применяем функцию, вычисляя значения AUC
auc_values = importance_auc(X_train, y_train, 'median')
auc_values
# Out:
# var15                            0.698
# saldo_var30                      0.697
# num_meses_var5_ult3              0.694
# num_var30                        0.682
# saldo_var42                      0.682
# saldo_var5                       0.677
# saldo_medio_var5_hace2           0.677
# saldo_medio_var5_ult3            0.676
# saldo_medio_var5_ult1            0.676
# ind_var30                        0.675
# saldo_medio_var5_hace3           0.672
# num_var42                        0.672
# ind_var5                         0.667
# num_var5                         0.667
# num_var35                        0.648
# num_var4                         0.648
# var36                            0.619
# var38                            0.585
# num_var30_0                      0.537
# ind_var39_0                      0.531
# ind_var41_0                      0.530
# num_var39_0                      0.530
# num_var41_0                      0.530
# ind_var12_0                      0.527
# num_var12_0                      0.527
# num_var13_0                      0.524
# ind_var13_0                      0.524
# num_var13                        0.523
# saldo_var13                      0.523
# ind_var13                        0.523
# num_var42_0                      0.523
# num_var8_0                       0.520
# ind_var8_0                       0.520
# saldo_var12                      0.520
# num_var12                        0.520
# ind_var12                        0.520
# num_meses_var13_corto_ult3       0.519
# num_var13_corto_0                0.519
# ind_var13_corto_0                0.519
# imp_trans_var37_ult1             0.519
# saldo_medio_var13_corto_ult1     0.519
# saldo_medio_var13_corto_ult3     0.519
# saldo_medio_var12_ult3           0.519
# saldo_medio_var12_ult1           0.519
# saldo_var13_corto                0.519
# num_var13_corto                  0.519
# ind_var13_corto                  0.519
# ind_var43_recib_ult1             0.518
# num_meses_var12_ult3             0.518
# num_var43_recib_ult1             0.518
# saldo_medio_var13_corto_hace2    0.518
# saldo_var24                      0.517
# num_var24                        0.517
# ind_var24                        0.517
# num_var24_0                      0.517
# ind_var24_0                      0.517
# saldo_medio_var12_hace2          0.516
# num_var5_0                       0.516
# ind_var5_0                       0.516
# imp_op_var41_efect_ult3          0.512
# imp_op_var39_efect_ult3          0.512
# num_meses_var8_ult3              0.512
# imp_op_var39_efect_ult1          0.511
# imp_op_var41_efect_ult1          0.511
# imp_aport_var13_hace3            0.511
# num_aport_var13_hace3            0.511
# num_var8                         0.511
# ind_var8                         0.511
# num_op_var41_efect_ult3          0.511
# num_op_var39_efect_ult3          0.511
# num_op_var39_efect_ult1          0.511
# num_op_var41_efect_ult1          0.510
# ind_var26_cte                    0.510
# ind_var25_cte                    0.509
# ind_var14_0                      0.509
# saldo_medio_var13_corto_hace3    0.509
# num_var45_hace3                  0.508
# ind_var10_ult1                   0.508
# num_var26                        0.508
# num_var26_0                      0.508
# ind_var26                        0.508
# ind_var26_0                      0.508
# saldo_var26                      0.508
# ind_var10cte_ult1                0.507
# num_var25                        0.507
# num_var25_0                      0.507
# ind_var25                        0.507
# ind_var25_0                      0.507
# saldo_var25                      0.507
# ind_var9_ult1                    0.507
# ind_var9_cte_ult1                0.506
# imp_var43_emit_ult1              0.506
# ind_var43_emit_ult1              0.506
# num_var43_emit_ult1              0.506
# num_var22_ult1                   0.506
# saldo_medio_var12_hace3          0.506
# num_trasp_var11_ult1             0.505
# num_var13_largo_0                0.505
# ind_var13_largo_0                0.505
# num_var13_largo                  0.505
# ind_var13_largo                  0.505
# saldo_var13_largo                0.505
# num_ent_var16_ult1               0.504
# num_meses_var39_vig_ult3         0.504
# num_meses_var13_largo_ult3       0.504
# saldo_medio_var13_largo_ult3     0.504
# saldo_medio_var13_largo_ult1     0.504
# saldo_medio_var13_largo_hace2    0.503
# ind_var37_0                      0.503
# ind_var37                        0.503
# ind_var19                        0.502
# saldo_medio_var13_largo_hace3    0.502
# imp_aport_var13_ult1             0.502
# num_aport_var13_ult1             0.502
# num_var20_0                      0.502
# ind_var20_0                      0.502
# imp_op_var40_efect_ult1          0.502
# num_op_var40_efect_ult1          0.502
# num_var22_hace3                  0.502
# num_op_var40_efect_ult3          0.502
# imp_op_var40_efect_ult3          0.502
# ind_var31_0                      0.502
# num_var31_0                      0.502
# saldo_var40                      0.502
# saldo_var1                       0.501
# num_var39                        0.501
# num_var40                        0.501
# ind_var40                        0.501
# ind_var39                        0.501
# ind_var1                         0.501
# num_var1                         0.501
# saldo_var14                      0.501
# num_var14                        0.501
# ind_var14                        0.501
# ind_var20                        0.501
# num_var20                        0.501
# saldo_var20                      0.501
# ind_var31                        0.501
# saldo_var31                      0.501
# num_var31                        0.501
# ind_var30_0                      0.501
# imp_ent_var16_ult1               0.501
# imp_op_var40_ult1                0.501
# num_op_var40_ult1                0.501
# num_op_var40_ult3                0.501
# ind_var17_0                      0.501
# saldo_medio_var17_hace2          0.501
# num_meses_var44_ult3             0.501
# num_var44_0                      0.501
# ind_var44_0                      0.501
# num_meses_var17_ult3             0.501
# saldo_medio_var44_ult1           0.501
# saldo_medio_var44_ult3           0.501
# saldo_medio_var44_hace2          0.501
# saldo_var44                      0.501
# num_var44                        0.501
# ind_var44                        0.501
# num_op_var41_hace2               0.501
# ind_var17                        0.501
# num_med_var22_ult3               0.500
# ind_var33_0                      0.500
# num_var33_0                      0.500
# var21                            0.500
# saldo_var33                      0.500
# ind_var33                        0.500
# saldo_medio_var33_ult3           0.500
# saldo_medio_var33_ult1           0.500
# num_var33                        0.500
# num_meses_var33_ult3             0.500
# delta_num_reemb_var13_1y3        0.500
# delta_imp_reemb_var13_1y3        0.500
# num_reemb_var13_ult1             0.500
# imp_reemb_var13_ult1             0.500
# saldo_medio_var33_hace2          0.500
# imp_venta_var44_ult1             0.500
# num_venta_var44_ult1             0.500
# num_compra_var44_ult1            0.500
# imp_compra_var44_ult1            0.500
# delta_imp_venta_var44_1y3        0.500
# delta_num_venta_var44_1y3        0.500
# saldo_medio_var17_ult1           0.500
# imp_compra_var44_hace3           0.500
# saldo_medio_var44_hace3          0.500
# num_compra_var44_hace3           0.500
# saldo_var17                      0.500
# num_aport_var17_hace3            0.500
# imp_aport_var17_hace3            0.500
# saldo_medio_var33_hace3          0.500
# imp_aport_var33_hace3            0.500
# num_aport_var33_hace3            0.500
# saldo_medio_var17_hace3          0.500
# delta_num_compra_var44_1y3       0.500
# num_op_var39_hace2               0.500
# delta_imp_compra_var44_1y3       0.500
# ind_var6_0                       0.500
# num_var29_0                      0.500
# ind_var29_0                      0.500
# num_var6_0                       0.500
# num_aport_var33_ult1             0.500
# imp_aport_var33_ult1             0.500
# imp_trasp_var33_in_ult1          0.500
# num_trasp_var33_in_ult1          0.500
# imp_venta_var44_hace3            0.500
# num_venta_var44_hace3            0.500
# num_op_var40_hace3               0.500
# imp_trasp_var17_in_ult1          0.500
# delta_imp_trasp_var17_out_1y3    0.500
# num_trasp_var17_out_ult1         0.500
# num_trasp_var17_in_ult1          0.500
# imp_trasp_var17_out_ult1         0.500
# delta_num_trasp_var17_out_1y3    0.500
# ind_var7_emit_ult1               0.500
# imp_var7_emit_ult1               0.500
# num_var7_emit_ult1               0.500
# num_meses_var29_ult3             0.500
# delta_num_trasp_var33_in_1y3     0.500
# imp_trasp_var33_in_hace3         0.500
# num_trasp_var17_in_hace3         0.500
# delta_imp_trasp_var33_in_1y3     0.500
# num_trasp_var33_in_hace3         0.500
# imp_trasp_var17_in_hace3         0.500
# saldo_medio_var29_hace2          0.500
# saldo_medio_var29_ult1           0.500
# saldo_medio_var29_ult3           0.500
# num_var34_0                      0.500
# ind_var34_0                      0.500
# ind_var34                        0.500
# num_var34                        0.500
# saldo_var34                      0.500
# imp_amort_var34_ult1             0.500
# delta_imp_amort_var34_1y3        0.500
# delta_imp_trasp_var17_in_1y3     0.500
# delta_num_trasp_var17_in_1y3     0.500
# saldo_var2_ult1                  0.500
# ind_var2_0                       0.500
# ind_var2                         0.500
# saldo_medio_var13_medio_ult3     0.500
# ind_var6                         0.500
# saldo_var18                      0.500
# num_var18                        0.500
# num_meses_var13_medio_ult3       0.500
# ind_var29                        0.500
# saldo_medio_var13_medio_ult1     0.500
# ind_var13_medio                  0.500
# saldo_var28                      0.500
# ind_var18_0                      0.500
# ind_var18                        0.500
# ind_var27_0                      0.500
# saldo_var27                      0.500
# ind_var28_0                      0.500
# ind_var28                        0.500
# ind_var13_medio_0                0.500
# saldo_var13_medio                0.500
# saldo_var29                      0.500
# saldo_medio_var13_medio_hace3    0.500
# num_trasp_var17_out_hace3        0.500
# num_var41                        0.500
# num_var29                        0.500
# num_var27                        0.500
# num_trasp_var33_out_hace3        0.500
# num_var46_0                      0.500
# num_trasp_var33_out_ult1         0.500
# num_reemb_var33_ult1             0.500
# num_reemb_var33_hace3            0.500
# num_reemb_var17_hace3            0.500
# num_var46                        0.500
# num_reemb_var13_hace3            0.500
# num_var28                        0.500
# num_var28_0                      0.500
# saldo_var6                       0.500
# num_var27_0                      0.500
# saldo_medio_var13_medio_hace2    0.500
# ind_var27                        0.500
# imp_reemb_var13_hace3            0.500
# ind_var46_0                      0.500
# delta_num_trasp_var33_out_1y3    0.500
# delta_imp_reemb_var33_1y3        0.500
# num_var18_0                      0.500
# imp_trasp_var33_out_ult1         0.500
# imp_trasp_var33_out_hace3        0.500
# imp_trasp_var17_out_hace3        0.500
# delta_num_reemb_var33_1y3        0.500
# imp_reemb_var33_ult1             0.500
# saldo_medio_var29_hace3          0.500
# imp_reemb_var33_hace3            0.500
# imp_reemb_var17_hace3            0.500
# imp_amort_var18_hace3            0.500
# imp_amort_var18_ult1             0.500
# imp_amort_var34_hace3            0.500
# ind_var46                        0.500
# ind_var41                        0.500
# delta_imp_trasp_var33_out_1y3    0.500
# num_var2_0_ult1                  0.500
# num_var6                         0.500
# num_var13_medio_0                0.500
# saldo_var46                      0.500
# num_var2_ult1                    0.500
# num_var13_medio                  0.500
# saldo_var41                      0.500
# delta_imp_amort_var18_1y3        0.500
# delta_num_aport_var33_1y3        0.500
# delta_imp_aport_var33_1y3        0.500
# imp_var7_recib_ult1              0.500
# num_op_var40_hace2               0.500
# imp_sal_var16_ult1               0.500
# saldo_medio_var17_ult3           0.500
# num_var17_0                      0.500
# delta_num_aport_var17_1y3        0.500
# delta_imp_aport_var17_1y3        0.500
# delta_num_reemb_var17_1y3        0.500
# delta_imp_reemb_var17_1y3        0.500
# num_reemb_var17_ult1             0.500
# imp_reemb_var17_ult1             0.500
# imp_aport_var17_ult1             0.500
# num_aport_var17_ult1             0.500
# num_var32_0                      0.499
# num_var32                        0.499
# ind_var32_0                      0.499
# ind_var32                        0.499
# saldo_var32                      0.499
# num_sal_var16_ult1               0.499
# imp_op_var40_comer_ult1          0.499
# num_var17                        0.499
# ind_var7_recib_ult1              0.499
# num_var7_recib_ult1              0.499
# ind_var32_cte                    0.499
# num_var37_med_ult2               0.499
# imp_op_var41_ult1                0.499
# num_op_var40_comer_ult1          0.499
# imp_op_var40_comer_ult3          0.499
# num_op_var40_comer_ult3          0.499
# imp_op_var39_ult1                0.499
# saldo_medio_var8_hace3           0.498
# num_op_var39_hace3               0.498
# num_op_var41_hace3               0.498
# saldo_var37                      0.498
# num_op_var41_ult1                0.498
# num_var37_0                      0.498
# num_var37                        0.498
# ind_var40_0                      0.498
# num_var40_0                      0.498
# ind_var1_0                       0.498
# num_var1_0                       0.498
# num_op_var41_comer_ult3          0.498
# num_op_var39_ult1                0.497
# num_var22_hace2                  0.497
# num_op_var41_ult3                0.497
# num_op_var39_ult3                0.497
# num_op_var39_comer_ult3          0.497
# ind_var37_cte                    0.496
# num_op_var41_comer_ult1          0.496
# imp_op_var41_comer_ult1          0.496
# num_op_var39_comer_ult1          0.496
# var3                             0.495
# imp_op_var39_comer_ult1          0.495
# num_var14_0                      0.495
# saldo_medio_var8_hace2           0.495
# num_var22_ult3                   0.494
# imp_op_var41_comer_ult3          0.491
# delta_imp_aport_var13_1y3        0.491
# delta_num_aport_var13_1y3        0.491
# imp_op_var39_comer_ult3          0.491
# saldo_var8                       0.491
# saldo_medio_var8_ult3            0.490
# saldo_medio_var8_ult1            0.490
# num_var45_hace2                  0.486
# num_med_var45_ult3               0.480
# num_var45_ult1                   0.474
# num_var45_ult3                   0.474
# dtype: float64

# %%
# отбираем столбцы с AUC выше 0.5
select_columns = auc_values.index[auc_values > 0.5].tolist()
# вычисляем количество отобранных столбцов
len(select_columns)
# Out:
# 233
