# %%
# импортируем polars и pandas
import polars as pl
import pandas as pd

# %%
# %%time

# считываем файл в датафрейм pandas
pandas_df = pd.read_csv('Data/train_data.csv')
# Out:
# CPU times: user 2min 2s, sys: 38.7 s, total: 2min 40s
# Wall time: 2min 58s

# %%
# %%time

# считываем файл в датафрейм polars
polars_df = pl.read_csv('Data/train_data.csv')
# Out:
# CPU times: user 1min 22s, sys: 1min 21s, total: 2min 44s
# Wall time: 25.9 s

# %%
# %%time

# считываем файл в датафрейм polars, потом в датафрейм pandas
pandas_df = pl.read_csv('Data/train_data.csv', rechunk=False).to_pandas()
# Out:
# CPU times: user 1min 30s, sys: 2min 19s, total: 3min 50s
# Wall time: 45.9 s

# %%
# смотрим первые 5 наблюдений
polars_df.head()
# Out:
# shape: (5, 190)
# ┌────────────────┬────────────┬──────────┬──────────┬─────┬───────┬──────────┬──────────┬──────────┐
# │ customer_ID    ┆ S_2        ┆ P_2      ┆ D_39     ┆ ... ┆ D_142 ┆ D_143    ┆ D_144    ┆ D_145    │
# │ ---            ┆ ---        ┆ ---      ┆ ---      ┆     ┆ ---   ┆ ---      ┆ ---      ┆ ---      │
# │ str            ┆ str        ┆ f64      ┆ f64      ┆     ┆ str   ┆ f64      ┆ f64      ┆ f64      │
# ╞════════════════╪════════════╪══════════╪══════════╪═════╪═══════╪══════════╪══════════╪══════════╡
# │ 0000099d6bd597 ┆ 2017-03-09 ┆ 0.938469 ┆ 0.001733 ┆ ... ┆ null  ┆ 0.000569 ┆ 0.00061  ┆ 0.002674 │
# │ 052cdcda90ffab ┆            ┆          ┆          ┆     ┆       ┆          ┆          ┆          │
# │ f565...        ┆            ┆          ┆          ┆     ┆       ┆          ┆          ┆          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 0000099d6bd597 ┆ 2017-04-07 ┆ 0.936665 ┆ 0.005775 ┆ ... ┆ null  ┆ 0.009576 ┆ 0.005492 ┆ 0.009217 │
# │ 052cdcda90ffab ┆            ┆          ┆          ┆     ┆       ┆          ┆          ┆          │
# │ f565...        ┆            ┆          ┆          ┆     ┆       ┆          ┆          ┆          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 0000099d6bd597 ┆ 2017-05-28 ┆ 0.95418  ┆ 0.091505 ┆ ... ┆ null  ┆ 0.003429 ┆ 0.006986 ┆ 0.002603 │
# │ 052cdcda90ffab ┆            ┆          ┆          ┆     ┆       ┆          ┆          ┆          │
# │ f565...        ┆            ┆          ┆          ┆     ┆       ┆          ┆          ┆          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 0000099d6bd597 ┆ 2017-06-13 ┆ 0.960384 ┆ 0.002455 ┆ ... ┆ null  ┆ 0.008419 ┆ 0.006527 ┆ 0.0096   │
# │ 052cdcda90ffab ┆            ┆          ┆          ┆     ┆       ┆          ┆          ┆          │
# │ f565...        ┆            ┆          ┆          ┆     ┆       ┆          ┆          ┆          │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┤
# │ 0000099d6bd597 ┆ 2017-07-16 ┆ 0.947248 ┆ 0.002483 ┆ ... ┆ null  ┆ 0.00167  ┆ 0.008126 ┆ 0.009827 │
# │ 052cdcda90ffab ┆            ┆          ┆          ┆     ┆       ┆          ┆          ┆          │
# │ f565...        ┆            ┆          ┆          ┆     ┆       ┆          ┆          ┆          │
# └────────────────┴────────────┴──────────┴──────────┴─────┴───────┴──────────┴──────────┴──────────┘

# %%
# %%time

# считываем файл
df = pl.read_csv('https://j.mp/iriscsv')
# вычисляем групповые статистики в режиме Eager
print(df.filter(pl.col('sepal_length') > 5)
      .groupby('species')
      .agg(pl.all().sum())
)
# Out:
# shape: (3, 5)
# ┌────────────┬──────────────┬─────────────┬──────────────┬─────────────┐
# │ species    ┆ sepal_length ┆ sepal_width ┆ petal_length ┆ petal_width │
# │ ---        ┆ ---          ┆ ---         ┆ ---          ┆ ---         │
# │ str        ┆ f64          ┆ f64         ┆ f64          ┆ f64         │
# ╞════════════╪══════════════╪═════════════╪══════════════╪═════════════╡
# │ virginica  ┆ 324.5        ┆ 146.2       ┆ 273.1        ┆ 99.6        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ setosa     ┆ 116.9        ┆ 81.7        ┆ 33.2         ┆ 6.1         │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ versicolor ┆ 281.9        ┆ 131.8       ┆ 202.9        ┆ 63.3        │
# └────────────┴──────────────┴─────────────┴──────────────┴─────────────┘
# CPU times: user 36.6 ms, sys: 30.4 ms, total: 67 ms
# Wall time: 1.45 s

# %%
# вычисляем групповые статистики в режиме Lazy
print(
    pl.read_csv('https://j.mp/iriscsv')
    .lazy()
    .filter(pl.col('sepal_length') > 5)
    .groupby('species')
    .agg(pl.all().sum())
    .collect()
)
# Out:
# shape: (3, 5)
# ┌────────────┬──────────────┬─────────────┬──────────────┬─────────────┐
# │ species    ┆ sepal_length ┆ sepal_width ┆ petal_length ┆ petal_width │
# │ ---        ┆ ---          ┆ ---         ┆ ---          ┆ ---         │
# │ str        ┆ f64          ┆ f64         ┆ f64          ┆ f64         │
# ╞════════════╪══════════════╪═════════════╪══════════════╪═════════════╡
# │ virginica  ┆ 324.5        ┆ 146.2       ┆ 273.1        ┆ 99.6        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ versicolor ┆ 281.9        ┆ 131.8       ┆ 202.9        ┆ 63.3        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ setosa     ┆ 116.9        ┆ 81.7        ┆ 33.2         ┆ 6.1         │
# └────────────┴──────────────┴─────────────┴──────────────┴─────────────┘

# %%
# переходим от режима Eager к режиму Lazy
(
    df.lazy()
    .filter(pl.col('sepal_length') > 5)
    .groupby('species')
    .agg(pl.all().sum())
    .collect()
)
# Out:
# shape: (3, 5)
# ┌────────────┬──────────────┬─────────────┬──────────────┬─────────────┐
# │ species    ┆ sepal_length ┆ sepal_width ┆ petal_length ┆ petal_width │
# │ ---        ┆ ---          ┆ ---         ┆ ---          ┆ ---         │
# │ str        ┆ f64          ┆ f64         ┆ f64          ┆ f64         │
# ╞════════════╪══════════════╪═════════════╪══════════════╪═════════════╡
# │ versicolor ┆ 281.9        ┆ 131.8       ┆ 202.9        ┆ 63.3        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ virginica  ┆ 324.5        ┆ 146.2       ┆ 273.1        ┆ 99.6        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ setosa     ┆ 116.9        ┆ 81.7        ┆ 33.2         ┆ 6.1         │
# └────────────┴──────────────┴─────────────┴──────────────┴─────────────┘
