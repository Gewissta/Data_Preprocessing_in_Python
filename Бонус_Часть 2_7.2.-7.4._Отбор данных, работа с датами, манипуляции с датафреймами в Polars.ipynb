# %%
# импортируем polars
import polars as pl
# импортируем класс datetime из модуля datetime
from datetime import datetime
# импортируем функцию display()
from IPython.display import display

# %%
# создаем датафрейм
df = pl.DataFrame(
    {
        'id': [1, 2, 3],
        'color': ['blue', 'red', 'green'],
        'size': ['small', 'medium', 'large'],
    }
)
print(df)
# Out:
# shape: (3, 3)
# ┌─────┬───────┬────────┐
# │ id  ┆ color ┆ size   │
# │ --- ┆ ---   ┆ ---    │
# │ i64 ┆ str   ┆ str    │
# ╞═════╪═══════╪════════╡
# │ 1   ┆ blue  ┆ small  │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ 2   ┆ red   ┆ medium │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ 3   ┆ green ┆ large  │
# └─────┴───────┴────────┘

# %%
# отбираем первые две строки
filter_df = df.filter(pl.col('id') <= 2)
print(filter_df)
# Out:
# shape: (2, 3)
# ┌─────┬───────┬────────┐
# │ id  ┆ color ┆ size   │
# │ --- ┆ ---   ┆ ---    │
# │ i64 ┆ str   ┆ str    │
# ╞═════╪═══════╪════════╡
# │ 1   ┆ blue  ┆ small  │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ 2   ┆ red   ┆ medium │
# └─────┴───────┴────────┘

# %%
# отбираем строки, в которых id меньше 
# или равен 0 и size равен small
multi_filter_df = df.filter((pl.col('id') <= 2) 
                            & (pl.col('size') == 'small'))
print(multi_filter_df)
# Out:
# shape: (1, 3)
# ┌─────┬───────┬───────┐
# │ id  ┆ color ┆ size  │
# │ --- ┆ ---   ┆ ---   │
# │ i64 ┆ str   ┆ str   │
# ╞═════╪═══════╪═══════╡
# │ 1   ┆ blue  ┆ small │
# └─────┴───────┴───────┘

# %%
# отбираем один столбец
single_select_df = df.select('id')
print(single_select_df)
# Out:
# shape: (3, 1)
# ┌─────┐
# │ id  │
# │ --- │
# │ i64 │
# ╞═════╡
# │ 1   │
# ├╌╌╌╌╌┤
# │ 2   │
# ├╌╌╌╌╌┤
# │ 3   │
# └─────┘

# %%
# отбираем столбцы по списку
list_select_df = df.select(['id', 'color'])
print(list_select_df)
# Out:
# shape: (3, 2)
# ┌─────┬───────┐
# │ id  ┆ color │
# │ --- ┆ ---   │
# │ i64 ┆ str   │
# ╞═════╪═══════╡
# │ 1   ┆ blue  │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 2   ┆ red   │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 3   ┆ green │
# └─────┴───────┘

# %%
# отбираем с помощью выражения - условия
condition_select_df = df.select(pl.col('^col.*$'))
print(condition_select_df)
# Out:
# shape: (3, 1)
# ┌───────┐
# │ color │
# │ ---   │
# │ str   │
# ╞═══════╡
# │ blue  │
# ├╌╌╌╌╌╌╌┤
# │ red   │
# ├╌╌╌╌╌╌╌┤
# │ green │
# └───────┘

# %%
# отберем столбцы по типу
dtype_select_df = df.select(pl.col(pl.Int64))
print(dtype_select_df)
# Out:
# shape: (3, 1)
# ┌─────┐
# │ id  │
# │ --- │
# │ i64 │
# ╞═════╡
# │ 1   │
# ├╌╌╌╌╌┤
# │ 2   │
# ├╌╌╌╌╌┤
# │ 3   │
# └─────┘

# %%
# отбираем строки и столбцы
expression_df = df.filter(pl.col('id') <= 2).select(['id', 'color'])
print(expression_df)
# Out:
# shape: (2, 2)
# ┌─────┬───────┐
# │ id  ┆ color │
# │ --- ┆ ---   │
# │ i64 ┆ str   │
# ╞═════╪═══════╡
# │ 1   ┆ blue  │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 2   ┆ red   │
# └─────┴───────┘

# %%
# загружаем данные
df = pl.read_csv('Data/applestock.csv', parse_dates=True)
print(df)
# Out:
# shape: (8933, 7)
# ┌────────────┬───────────┬───────────┬───────────┬───────────┬───────────┬───────────┐
# │ Date       ┆ Open      ┆ High      ┆ Low       ┆ Close     ┆ Volume    ┆ Adj Close │
# │ ---        ┆ ---       ┆ ---       ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ date       ┆ f64       ┆ f64       ┆ f64       ┆ f64       ┆ i64       ┆ f64       │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2016-05-16 ┆ 92.389999 ┆ 94.389999 ┆ 91.650002 ┆ 93.879997 ┆ 61140600  ┆ 93.879997 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 2016-05-13 ┆ 90.0      ┆ 91.669998 ┆ 90.0      ┆ 90.519997 ┆ 44188200  ┆ 90.519997 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 2016-05-12 ┆ 92.720001 ┆ 92.779999 ┆ 89.470001 ┆ 90.339996 ┆ 76109800  ┆ 90.339996 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 2016-05-11 ┆ 93.480003 ┆ 93.57     ┆ 92.459999 ┆ 92.510002 ┆ 28539900  ┆ 92.510002 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...        ┆ ...       ┆ ...       ┆ ...       ┆ ...       ┆ ...       ┆ ...       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1980-12-17 ┆ 25.875    ┆ 25.999999 ┆ 25.875    ┆ 25.875    ┆ 21610400  ┆ 0.388222  │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1980-12-16 ┆ 25.375    ┆ 25.375    ┆ 25.25     ┆ 25.25     ┆ 26432000  ┆ 0.378845  │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1980-12-15 ┆ 27.375001 ┆ 27.375001 ┆ 27.25     ┆ 27.25     ┆ 43971200  ┆ 0.408852  │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1980-12-12 ┆ 28.75     ┆ 28.875    ┆ 28.75     ┆ 28.75     ┆ 117258400 ┆ 0.431358  │
# └────────────┴───────────┴───────────┴───────────┴───────────┴───────────┴───────────┘

# %%
# загружаем данные, даты обрабатываются как строки
df = pl.read_csv('Data/applestock.csv', parse_dates=False)
# переводим в тип Date
df = df.with_column(pl.col('Date').str.strptime(
    pl.Date, fmt='%Y-%m-%d'))
print(df)
# Out:
# shape: (8933, 7)
# ┌────────────┬───────────┬───────────┬───────────┬───────────┬───────────┬───────────┐
# │ Date       ┆ Open      ┆ High      ┆ Low       ┆ Close     ┆ Volume    ┆ Adj Close │
# │ ---        ┆ ---       ┆ ---       ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ date       ┆ f64       ┆ f64       ┆ f64       ┆ f64       ┆ i64       ┆ f64       │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2016-05-16 ┆ 92.389999 ┆ 94.389999 ┆ 91.650002 ┆ 93.879997 ┆ 61140600  ┆ 93.879997 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 2016-05-13 ┆ 90.0      ┆ 91.669998 ┆ 90.0      ┆ 90.519997 ┆ 44188200  ┆ 90.519997 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 2016-05-12 ┆ 92.720001 ┆ 92.779999 ┆ 89.470001 ┆ 90.339996 ┆ 76109800  ┆ 90.339996 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 2016-05-11 ┆ 93.480003 ┆ 93.57     ┆ 92.459999 ┆ 92.510002 ┆ 28539900  ┆ 92.510002 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...        ┆ ...       ┆ ...       ┆ ...       ┆ ...       ┆ ...       ┆ ...       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1980-12-17 ┆ 25.875    ┆ 25.999999 ┆ 25.875    ┆ 25.875    ┆ 21610400  ┆ 0.388222  │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1980-12-16 ┆ 25.375    ┆ 25.375    ┆ 25.25     ┆ 25.25     ┆ 26432000  ┆ 0.378845  │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1980-12-15 ┆ 27.375001 ┆ 27.375001 ┆ 27.25     ┆ 27.25     ┆ 43971200  ┆ 0.408852  │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1980-12-12 ┆ 28.75     ┆ 28.875    ┆ 28.75     ┆ 28.75     ┆ 117258400 ┆ 0.431358  │
# └────────────┴───────────┴───────────┴───────────┴───────────┴───────────┴───────────┘

# %%
# создаем календарные признаки
df = df.with_columns([
    (pl.col('Date').dt.year()).alias('year'),
    (pl.col('Date').dt.quarter()).alias('quarter'),
    (pl.col('Date').dt.month()).alias('month'),
    (pl.col('Date').dt.week()).alias('week'),
    (pl.col('Date').dt.weekday()).alias('weekday'),
    (pl.col('Date').dt.day()).alias('dayofmonth'),
    (pl.col('Date').dt.ordinal_day().alias('dayofyear'))
])
df = df.with_column(
    (pl.when(pl.col('weekday') > 5).then(1).otherwise(0)).alias('weekend'))
df
# Out:
# shape: (8933, 15)
# ┌─────────────┬─────────────┬─────────────┬─────────────┬─────┬─────────┬──────────┬─────┬─────────┐
# │ Date        ┆ Open        ┆ High        ┆ Low         ┆ ... ┆ weekday ┆ dayofmon ┆ day ┆ weekend │
# │ ---         ┆ ---         ┆ ---         ┆ ---         ┆     ┆ ---     ┆ th       ┆ ofy ┆ ---     │
# │ date        ┆ f64         ┆ f64         ┆ f64         ┆     ┆ u32     ┆ ---      ┆ ear ┆ i64     │
# │             ┆             ┆             ┆             ┆     ┆         ┆ u32      ┆ --- ┆         │
# │             ┆             ┆             ┆             ┆     ┆         ┆          ┆ u32 ┆         │
# ╞═════════════╪═════════════╪═════════════╪═════════════╪═════╪═════════╪══════════╪═════╪═════════╡
# │ 2016-05-16  ┆ 92.389999   ┆ 94.389999   ┆ 91.650002   ┆ ... ┆ 0       ┆ 16       ┆ 137 ┆ 0       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 2016-05-13  ┆ 90.0        ┆ 91.669998   ┆ 90.0        ┆ ... ┆ 4       ┆ 13       ┆ 134 ┆ 0       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 2016-05-12  ┆ 92.720001   ┆ 92.779999   ┆ 89.470001   ┆ ... ┆ 3       ┆ 12       ┆ 133 ┆ 0       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 2016-05-11  ┆ 93.480003   ┆ 93.57       ┆ 92.459999   ┆ ... ┆ 2       ┆ 11       ┆ 132 ┆ 0       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ ...         ┆ ...         ┆ ...         ┆ ...         ┆ ... ┆ ...     ┆ ...      ┆ ... ┆ ...     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 1980-12-17  ┆ 25.875      ┆ 25.999999   ┆ 25.875      ┆ ... ┆ 2       ┆ 17       ┆ 352 ┆ 0       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 1980-12-16  ┆ 25.375      ┆ 25.375      ┆ 25.25       ┆ ... ┆ 1       ┆ 16       ┆ 351 ┆ 0       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 1980-12-15  ┆ 27.375001   ┆ 27.375001   ┆ 27.25       ┆ ... ┆ 0       ┆ 15       ┆ 350 ┆ 0       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 1980-12-12  ┆ 28.75       ┆ 28.875      ┆ 28.75       ┆ ... ┆ 4       ┆ 12       ┆ 347 ┆ 0       │
# └─────────────┴─────────────┴─────────────┴─────────────┴─────┴─────────┴──────────┴─────┴─────────┘

# %%
# отбираем определенный диапазон дат
filtered_range_df = df.filter(pl.col('Date').is_between(
    datetime(1995, 7, 1), datetime(1995, 11, 1)))
filtered_range_df
# Out:
# shape: (85, 15)
# ┌─────────────┬─────────────┬─────────────┬─────────────┬─────┬─────────┬──────────┬─────┬─────────┐
# │ Date        ┆ Open        ┆ High        ┆ Low         ┆ ... ┆ weekday ┆ dayofmon ┆ day ┆ weekend │
# │ ---         ┆ ---         ┆ ---         ┆ ---         ┆     ┆ ---     ┆ th       ┆ ofy ┆ ---     │
# │ date        ┆ f64         ┆ f64         ┆ f64         ┆     ┆ u32     ┆ ---      ┆ ear ┆ i64     │
# │             ┆             ┆             ┆             ┆     ┆         ┆ u32      ┆ --- ┆         │
# │             ┆             ┆             ┆             ┆     ┆         ┆          ┆ u32 ┆         │
# ╞═════════════╪═════════════╪═════════════╪═════════════╪═════╪═════════╪══════════╪═════╪═════════╡
# │ 1995-10-31  ┆ 35.249999   ┆ 36.625      ┆ 35.125      ┆ ... ┆ 1       ┆ 31       ┆ 304 ┆ 0       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 1995-10-30  ┆ 34.875      ┆ 35.249999   ┆ 34.625001   ┆ ... ┆ 0       ┆ 30       ┆ 303 ┆ 0       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 1995-10-27  ┆ 34.875      ┆ 34.875      ┆ 34.125      ┆ ... ┆ 4       ┆ 27       ┆ 300 ┆ 0       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 1995-10-26  ┆ 34.875      ┆ 35.0        ┆ 34.499999   ┆ ... ┆ 3       ┆ 26       ┆ 299 ┆ 0       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ ...         ┆ ...         ┆ ...         ┆ ...         ┆ ... ┆ ...     ┆ ...      ┆ ... ┆ ...     │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 1995-07-07  ┆ 46.875001   ┆ 49.249999   ┆ 46.749999   ┆ ... ┆ 4       ┆ 7        ┆ 188 ┆ 0       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 1995-07-06  ┆ 46.5        ┆ 47.000001   ┆ 45.749999   ┆ ... ┆ 3       ┆ 6        ┆ 187 ┆ 0       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 1995-07-05  ┆ 46.875001   ┆ 47.875001   ┆ 46.5        ┆ ... ┆ 2       ┆ 5        ┆ 186 ┆ 0       │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌┤
# │ 1995-07-03  ┆ 46.5        ┆ 47.125      ┆ 46.25       ┆ ... ┆ 0       ┆ 3        ┆ 184 ┆ 0       │
# └─────────────┴─────────────┴─────────────┴─────────────┴─────┴─────────┴──────────┴─────┴─────────┘

# %%
# отберем определенную дату
filtered_df = df.filter(pl.col('Date') == datetime(1995, 10, 16))
filtered_df
# Out:
# shape: (1, 15)
# ┌────────────┬───────────┬───────────┬────────┬─────┬─────────┬──────────┬─────┬─────────┐
# │ Date       ┆ Open      ┆ High      ┆ Low    ┆ ... ┆ weekday ┆ dayofmon ┆ day ┆ weekend │
# │ ---        ┆ ---       ┆ ---       ┆ ---    ┆     ┆ ---     ┆ th       ┆ ofy ┆ ---     │
# │ date       ┆ f64       ┆ f64       ┆ f64    ┆     ┆ u32     ┆ ---      ┆ ear ┆ i64     │
# │            ┆           ┆           ┆        ┆     ┆         ┆ u32      ┆ --- ┆         │
# │            ┆           ┆           ┆        ┆     ┆         ┆          ┆ u32 ┆         │
# ╞════════════╪═══════════╪═══════════╪════════╪═════╪═════════╪══════════╪═════╪═════════╡
# │ 1995-10-16 ┆ 36.249999 ┆ 36.999999 ┆ 35.875 ┆ ... ┆ 0       ┆ 16       ┆ 289 ┆ 0       │
# └────────────┴───────────┴───────────┴────────┴─────┴─────────┴──────────┴─────┴─────────┘

# %%
# выполним конкатенацию датафреймов по вертикали
df_v1 = pl.DataFrame(
    {
        'a': [1],
        'b': [3],
    }
)

df_v2 = pl.DataFrame(
    {
        'a': [2],
        'b': [4],
    }
)

df_vertical_concat = pl.concat(
    [
        df_v1,
        df_v2,
    ],
    how='vertical'
)

display(df_v1, df_v2, df_vertical_concat)
# Out:
# shape: (1, 2)
# ┌─────┬─────┐
# │ a   ┆ b   │
# │ --- ┆ --- │
# │ i64 ┆ i64 │
# ╞═════╪═════╡
# │ 1   ┆ 3   │
# └─────┴─────┘
# shape: (1, 2)
# ┌─────┬─────┐
# │ a   ┆ b   │
# │ --- ┆ --- │
# │ i64 ┆ i64 │
# ╞═════╪═════╡
# │ 2   ┆ 4   │
# └─────┴─────┘
# shape: (2, 2)
# ┌─────┬─────┐
# │ a   ┆ b   │
# │ --- ┆ --- │
# │ i64 ┆ i64 │
# ╞═════╪═════╡
# │ 1   ┆ 3   │
# ├╌╌╌╌╌┼╌╌╌╌╌┤
# │ 2   ┆ 4   │
# └─────┴─────┘

# %%
# выполним конкатенацию датафреймов по горизонтали
df_h1 = pl.DataFrame(
    {
        'l1': [1, 2],
        'l2': [3, 4],
    }
)

df_h2 = pl.DataFrame(
    {
        'r1': [5, 6],
        'r2': [7, 8],
        'r3': [9, 10],
    }
)

df_horizontal_concat = pl.concat(
    [
        df_h1,
        df_h2,
    ],
    how='horizontal'
)

display(df_h1, df_h2, df_horizontal_concat)
# Out:
# shape: (2, 2)
# ┌─────┬─────┐
# │ l1  ┆ l2  │
# │ --- ┆ --- │
# │ i64 ┆ i64 │
# ╞═════╪═════╡
# │ 1   ┆ 3   │
# ├╌╌╌╌╌┼╌╌╌╌╌┤
# │ 2   ┆ 4   │
# └─────┴─────┘
# shape: (2, 3)
# ┌─────┬─────┬─────┐
# │ r1  ┆ r2  ┆ r3  │
# │ --- ┆ --- ┆ --- │
# │ i64 ┆ i64 ┆ i64 │
# ╞═════╪═════╪═════╡
# │ 5   ┆ 7   ┆ 9   │
# ├╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌┤
# │ 6   ┆ 8   ┆ 10  │
# └─────┴─────┴─────┘
# shape: (2, 5)
# ┌─────┬─────┬─────┬─────┬─────┐
# │ l1  ┆ l2  ┆ r1  ┆ r2  ┆ r3  │
# │ --- ┆ --- ┆ --- ┆ --- ┆ --- │
# │ i64 ┆ i64 ┆ i64 ┆ i64 ┆ i64 │
# ╞═════╪═════╪═════╪═════╪═════╡
# │ 1   ┆ 3   ┆ 5   ┆ 7   ┆ 9   │
# ├╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌┤
# │ 2   ┆ 4   ┆ 6   ┆ 8   ┆ 10  │
# └─────┴─────┴─────┴─────┴─────┘

# %%
# выполним конкатенацию датафреймов по диагонали
df_d1 = pl.DataFrame(
    {
        'a': [1],
        'b': [3],
    }
)

df_d2 = pl.DataFrame(
    {
        'a': [2],
        'd': [4],
    }
)

df_diagonal_concat = pl.concat(
    [
        df_d1,
        df_d2,
    ],
    how='diagonal',
)

display(df_d1, df_d2, df_diagonal_concat)
# Out:
# shape: (1, 2)
# ┌─────┬─────┐
# │ a   ┆ b   │
# │ --- ┆ --- │
# │ i64 ┆ i64 │
# ╞═════╪═════╡
# │ 1   ┆ 3   │
# └─────┴─────┘
# shape: (1, 2)
# ┌─────┬─────┐
# │ a   ┆ d   │
# │ --- ┆ --- │
# │ i64 ┆ i64 │
# ╞═════╪═════╡
# │ 2   ┆ 4   │
# └─────┴─────┘
# shape: (2, 3)
# ┌─────┬──────┬──────┐
# │ a   ┆ b    ┆ d    │
# │ --- ┆ ---  ┆ ---  │
# │ i64 ┆ i64  ┆ i64  │
# ╞═════╪══════╪══════╡
# │ 1   ┆ 3    ┆ null │
# ├╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ 2   ┆ null ┆ 4    │
# └─────┴──────┴──────┘

# %%
# датафрейм - идентификатор и марка машины
df_cars = pl.DataFrame(
    {
        'id': ['a', 'b', 'c'],
        'make': ['ford', 'toyota', 'bmw'],
    }
)
print(df_cars)
# Out:
# shape: (3, 2)
# ┌─────┬────────┐
# │ id  ┆ make   │
# │ --- ┆ ---    │
# │ str ┆ str    │
# ╞═════╪════════╡
# │ a   ┆ ford   │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ b   ┆ toyota │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ c   ┆ bmw    │
# └─────┴────────┘

# %%
# датафрейм - идентификатор и стоимость ремонта
df_repairs = pl.DataFrame(
    {
        'id': ['c', 'c'],
        'cost': [100, 200],
    }
)
print(df_repairs)
# Out:
# shape: (2, 2)
# ┌─────┬──────┐
# │ id  ┆ cost │
# │ --- ┆ ---  │
# │ str ┆ i64  │
# ╞═════╪══════╡
# │ c   ┆ 100  │
# ├╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ c   ┆ 200  │
# └─────┴──────┘

# %%
# применим inner join
df_inner_join = df_cars.join(df_repairs, on='id', how='inner')
print(df_inner_join)
# Out:
# shape: (2, 3)
# ┌─────┬──────┬──────┐
# │ id  ┆ make ┆ cost │
# │ --- ┆ ---  ┆ ---  │
# │ str ┆ str  ┆ i64  │
# ╞═════╪══════╪══════╡
# │ c   ┆ bmw  ┆ 100  │
# ├╌╌╌╌╌┼╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ c   ┆ bmw  ┆ 200  │
# └─────┴──────┴──────┘

# %%
# применим outer join
df_outer_join = df_cars.join(df_repairs, on='id', how='outer')
print(df_outer_join)
# Out:
# shape: (4, 3)
# ┌─────┬────────┬──────┐
# │ id  ┆ make   ┆ cost │
# │ --- ┆ ---    ┆ ---  │
# │ str ┆ str    ┆ i64  │
# ╞═════╪════════╪══════╡
# │ a   ┆ ford   ┆ null │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ b   ┆ toyota ┆ null │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ c   ┆ bmw    ┆ 100  │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ c   ┆ bmw    ┆ 200  │
# └─────┴────────┴──────┘

# %%
# применим semi join
df_semi_join = df_cars.join(df_repairs, on='id', how='semi')
print(df_semi_join)
# Out:
# shape: (1, 2)
# ┌─────┬──────┐
# │ id  ┆ make │
# │ --- ┆ ---  │
# │ str ┆ str  │
# ╞═════╪══════╡
# │ c   ┆ bmw  │
# └─────┴──────┘

# %%
# применим anti join
df_anti_join = df_cars.join(df_repairs, on='id', how='anti')
print(df_anti_join)
# Out:
# shape: (2, 2)
# ┌─────┬────────┐
# │ id  ┆ make   │
# │ --- ┆ ---    │
# │ str ┆ str    │
# ╞═════╪════════╡
# │ a   ┆ ford   │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ b   ┆ toyota │
# └─────┴────────┘
